# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/youtube_ad_revenue_dataset.csv")
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122400 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              122400 non-null  object
#  1   date                  122400 non-null  object
#  2   views                 122400 non-null  int64
#  3   likes                 116283 non-null  float64
#  4   comments              116288 non-null  float64
#  5   watch_time_minutes    116295 non-null  float64
#  6   video_length_minutes  122400 non-null  float64
#  7   subscribers           122400 non-null  int64
#  8   category              122400 non-null  object
#  9   device                122400 non-null  object
#  10  country               122400 non-null  object
#  11  ad_revenue_usd        122400 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#                views          likes       comments  watch_time_minutes  \
# count  122400.000000  116283.000000  116288.000000       116295.000000
# mean     9999.856283    1099.633618     274.396636        37543.827721
# std        99.881260     519.424089     129.741739        12987.724246
# min      9521.000000     195.000000      48.000000        14659.105562
# 25%      9933.000000     650.000000     162.000000        26366.320569
# 50%     10000.000000    1103.000000     274.000000        37531.990337
# 75%     10067.000000    1547.000000     387.000000        48777.782090
# max     10468.000000    2061.000000     515.000000        61557.670089
#
#        video_length_minutes    subscribers  ad_revenue_usd
# count         122400.000000  122400.000000   122400.000000
# mean              16.014165  502191.719902      252.727210
# std                8.083790  288397.470103       61.957052
# min                2.000142    1005.000000      126.590603
# ...

# %%
df['likes'] = df['likes'].fillna(0)
df['comments'] = df['comments'].fillna(0)
df['watch_time_minutes'] = df['watch_time_minutes'].fillna(0)

# %%
df.isnull().sum()
# Out:
# video_id                0
# date                    0
# views                   0
# likes                   0
# comments                0
# watch_time_minutes      0
# video_length_minutes    0
# subscribers             0
# category                0
# device                  0
# country                 0
# ad_revenue_usd          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2400)

# %%
df = df.drop_duplicates()

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 119995  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 119996  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 119997  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       0.0
# 119998  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 119999  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       0.0
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
df['hour'] = df['date'].dt.hour
df['is_weekend'] = df['date'].dt.dayofweek >= 5

# %%
df
# Out:
#         video_id                       date  views   likes  comments  \
# 0       vid_3092 2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459 2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784 2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078 2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522 2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                        ...    ...     ...       ...
# 119995  vid_2902 2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 119996  vid_3890 2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 119997  vid_3934 2024-06-10 10:50:40.993199  10267   700.0       0.0
# 119998  vid_4260 2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 119999  vid_1056 2024-06-25 10:50:40.993199   9931   770.0       0.0
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
# Day	Value
# Monday	0
# Tuesday	1
# Wednesday	2
# Thursday	3
# Friday	4
# Saturday	5
# Sunday	6



# True → Saturday or Sunday

# False → Monday to Friday

# %%
df.drop(columns=['date'], inplace=True)

# %%
df
# Out:
#         video_id  views   likes  comments  watch_time_minutes  \
# 0       vid_3092   9936  1221.0     320.0        26497.214184
# 1       vid_3459  10017   642.0     346.0        15209.747445
# 2       vid_4784  10097  1979.0     187.0        57332.658498
# 3       vid_4078  10034  1191.0     242.0        31334.517771
# 4       vid_3522   9889  1858.0     477.0        15665.666434
# ...          ...    ...     ...       ...                 ...
# 119995  vid_2902   9853  1673.0     147.0        42075.704885
# 119996  vid_3890  10128  1709.0      63.0        57563.703040
# 119997  vid_3934  10267   700.0       0.0        27549.714659
# 119998  vid_4260  10240  1616.0     106.0        56967.384382
# 119999  vid_1056   9931   770.0       0.0        38466.837135
#
#         video_length_minutes  subscribers       category   device country  \
# 0                   2.862137       228086  Entertainment       TV      IN
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
df["category"]=encoder.fit_transform(df[["category"]])
df["device"]=encoder.fit_transform(df[["device"]])
df["country"]=encoder.fit_transform(df[["country"]])

# %%
df
# Out:
#         video_id  views   likes  comments  watch_time_minutes  \
# 0       vid_3092   9936  1221.0     320.0        26497.214184
# 1       vid_3459  10017   642.0     346.0        15209.747445
# 2       vid_4784  10097  1979.0     187.0        57332.658498
# 3       vid_4078  10034  1191.0     242.0        31334.517771
# 4       vid_3522   9889  1858.0     477.0        15665.666434
# ...          ...    ...     ...       ...                 ...
# 119995  vid_2902   9853  1673.0     147.0        42075.704885
# 119996  vid_3890  10128  1709.0      63.0        57563.703040
# 119997  vid_3934  10267   700.0       0.0        27549.714659
# 119998  vid_4260  10240  1616.0     106.0        56967.384382
# 119999  vid_1056   9931   770.0       0.0        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  \
# 0                   2.862137       228086       0.0     0.0      0.0
# 1                  23.738069       736015       0.0     0.0      0.0
# ...

# %%
col = 'ad_revenue_usd'

df = df[[c for c in df.columns if c != col] + [col]]

# %%
df
# Out:
#         video_id  views   likes  comments  watch_time_minutes  \
# 0       vid_3092   9936  1221.0     320.0        26497.214184
# 1       vid_3459  10017   642.0     346.0        15209.747445
# 2       vid_4784  10097  1979.0     187.0        57332.658498
# 3       vid_4078  10034  1191.0     242.0        31334.517771
# 4       vid_3522   9889  1858.0     477.0        15665.666434
# ...          ...    ...     ...       ...                 ...
# 119995  vid_2902   9853  1673.0     147.0        42075.704885
# 119996  vid_3890  10128  1709.0      63.0        57563.703040
# 119997  vid_3934  10267   700.0       0.0        27549.714659
# 119998  vid_4260  10240  1616.0     106.0        56967.384382
# 119999  vid_1056   9931   770.0       0.0        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  year  \
# 0                   2.862137       228086       0.0     0.0      0.0  2024
# ...

# %%
df['is_weekend'] = df['is_weekend'].astype(int)

# %%
df
# Out:
#         video_id  views   likes  comments  watch_time_minutes  \
# 0       vid_3092   9936  1221.0     320.0        26497.214184
# 1       vid_3459  10017   642.0     346.0        15209.747445
# 2       vid_4784  10097  1979.0     187.0        57332.658498
# 3       vid_4078  10034  1191.0     242.0        31334.517771
# 4       vid_3522   9889  1858.0     477.0        15665.666434
# ...          ...    ...     ...       ...                 ...
# 119995  vid_2902   9853  1673.0     147.0        42075.704885
# 119996  vid_3890  10128  1709.0      63.0        57563.703040
# 119997  vid_3934  10267   700.0       0.0        27549.714659
# 119998  vid_4260  10240  1616.0     106.0        56967.384382
# 119999  vid_1056   9931   770.0       0.0        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  year  \
# 0                   2.862137       228086       0.0     0.0      0.0  2024
# ...

# %%
df['Engagement_Rate'] = (df['likes'] + df['comments']) / df['views']

# %%
df
# Out:
#         video_id  views   likes  comments  watch_time_minutes  \
# 0       vid_3092   9936  1221.0     320.0        26497.214184
# 1       vid_3459  10017   642.0     346.0        15209.747445
# 2       vid_4784  10097  1979.0     187.0        57332.658498
# 3       vid_4078  10034  1191.0     242.0        31334.517771
# 4       vid_3522   9889  1858.0     477.0        15665.666434
# ...          ...    ...     ...       ...                 ...
# 119995  vid_2902   9853  1673.0     147.0        42075.704885
# 119996  vid_3890  10128  1709.0      63.0        57563.703040
# 119997  vid_3934  10267   700.0       0.0        27549.714659
# 119998  vid_4260  10240  1616.0     106.0        56967.384382
# 119999  vid_1056   9931   770.0       0.0        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  year  \
# 0                   2.862137       228086       0.0     0.0      0.0  2024
# ...

# %%
cols = list(df.columns)


# Find position right after "comments"
insert_pos = cols.index("comments") + 1

# Insert the column in the new position
cols.insert(insert_pos, "Engagement_Rate")

# Reorder dataframe
df = df[cols]

# %%
df
# Out:
#         video_id  views   likes  comments  Engagement_Rate  \
# 0       vid_3092   9936  1221.0     320.0         0.155093
# 1       vid_3459  10017   642.0     346.0         0.098632
# 2       vid_4784  10097  1979.0     187.0         0.214519
# 3       vid_4078  10034  1191.0     242.0         0.142814
# 4       vid_3522   9889  1858.0     477.0         0.236121
# ...          ...    ...     ...       ...              ...
# 119995  vid_2902   9853  1673.0     147.0         0.184715
# 119996  vid_3890  10128  1709.0      63.0         0.174961
# 119997  vid_3934  10267   700.0       0.0         0.068180
# 119998  vid_4260  10240  1616.0     106.0         0.168164
# 119999  vid_1056   9931   770.0       0.0         0.077535
#
#         watch_time_minutes  video_length_minutes  subscribers  category  \
# 0             26497.214184              2.862137       228086       0.0
# 1             15209.747445             23.738069       736015       0.0
# ...

# %%
df = df.drop(columns=['Engagement_Rate'])

# %%
df
# Out:
#         video_id  views   likes  comments  watch_time_minutes  \
# 0       vid_3092   9936  1221.0     320.0        26497.214184
# 1       vid_3459  10017   642.0     346.0        15209.747445
# 2       vid_4784  10097  1979.0     187.0        57332.658498
# 3       vid_4078  10034  1191.0     242.0        31334.517771
# 4       vid_3522   9889  1858.0     477.0        15665.666434
# ...          ...    ...     ...       ...                 ...
# 119995  vid_2902   9853  1673.0     147.0        42075.704885
# 119996  vid_3890  10128  1709.0      63.0        57563.703040
# 119997  vid_3934  10267   700.0       0.0        27549.714659
# 119998  vid_4260  10240  1616.0     106.0        56967.384382
# 119999  vid_1056   9931   770.0       0.0        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  year  \
# 0                   2.862137       228086       0.0     0.0      0.0  2024
# ...

# %%
df['Engagement_Rate'] = (df['likes'] + df['comments']) / df['views']

# %%
# Get all columns
cols = list(df.columns)

# Remove Engagement_Rate from current position
cols.remove("Engagement_Rate")

# Find position right after "comments"
insert_pos = cols.index("comments") + 1

# Insert the column in the new position
cols.insert(insert_pos, "Engagement_Rate")

# Reorder dataframe
df = df[cols]

# %%
df
# Out:
#         video_id  views   likes  comments  Engagement_Rate  \
# 0       vid_3092   9936  1221.0     320.0         0.155093
# 1       vid_3459  10017   642.0     346.0         0.098632
# 2       vid_4784  10097  1979.0     187.0         0.214519
# 3       vid_4078  10034  1191.0     242.0         0.142814
# 4       vid_3522   9889  1858.0     477.0         0.236121
# ...          ...    ...     ...       ...              ...
# 119995  vid_2902   9853  1673.0     147.0         0.184715
# 119996  vid_3890  10128  1709.0      63.0         0.174961
# 119997  vid_3934  10267   700.0       0.0         0.068180
# 119998  vid_4260  10240  1616.0     106.0         0.168164
# 119999  vid_1056   9931   770.0       0.0         0.077535
#
#         watch_time_minutes  video_length_minutes  subscribers  category  \
# 0             26497.214184              2.862137       228086       0.0
# 1             15209.747445             23.738069       736015       0.0
# ...

# %%
df
# Out:
#         video_id  views   likes  comments  Engagement_Rate  \
# 0       vid_3092   9936  1221.0     320.0         0.155093
# 1       vid_3459  10017   642.0     346.0         0.098632
# 2       vid_4784  10097  1979.0     187.0         0.214519
# 3       vid_4078  10034  1191.0     242.0         0.142814
# 4       vid_3522   9889  1858.0     477.0         0.236121
# ...          ...    ...     ...       ...              ...
# 119995  vid_2902   9853  1673.0     147.0         0.184715
# 119996  vid_3890  10128  1709.0      63.0         0.174961
# 119997  vid_3934  10267   700.0       0.0         0.068180
# 119998  vid_4260  10240  1616.0     106.0         0.168164
# 119999  vid_1056   9931   770.0       0.0         0.077535
#
#         watch_time_minutes  video_length_minutes  subscribers  category  \
# 0             26497.214184              2.862137       228086       0.0
# 1             15209.747445             23.738069       736015       0.0
# ...

# %%
df.drop("video_id", axis=1, inplace=True)
# Out:
# /tmp/ipython-input-1947078256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("video_id", axis=1, inplace=True)

# %%
df
# Out:
#         views   likes  comments  Engagement_Rate  watch_time_minutes  \
# 0        9936  1221.0     320.0         0.155093        26497.214184
# 1       10017   642.0     346.0         0.098632        15209.747445
# 2       10097  1979.0     187.0         0.214519        57332.658498
# 3       10034  1191.0     242.0         0.142814        31334.517771
# 4        9889  1858.0     477.0         0.236121        15665.666434
# ...       ...     ...       ...              ...                 ...
# 119995   9853  1673.0     147.0         0.184715        42075.704885
# 119996  10128  1709.0      63.0         0.174961        57563.703040
# 119997  10267   700.0       0.0         0.068180        27549.714659
# 119998  10240  1616.0     106.0         0.168164        56967.384382
# 119999   9931   770.0       0.0         0.077535        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  year  \
# ...

# %%
df.to_csv('cleaned_data_youtube_AD.csv', index=False)
from google.colab import files
files.download('cleaned_data_youtube_AD.csv')

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#         views   likes  comments  Engagement_Rate  watch_time_minutes  \
# 0        9936  1221.0     320.0         0.155093        26497.214184
# 1       10017   642.0     346.0         0.098632        15209.747445
# 2       10097  1979.0     187.0         0.214519        57332.658498
# 3       10034  1191.0     242.0         0.142814        31334.517771
# 4        9889  1858.0     477.0         0.236121        15665.666434
# ...       ...     ...       ...              ...                 ...
# 119995   9853  1673.0     147.0         0.184715        42075.704885
# 119996  10128  1709.0      63.0         0.174961        57563.703040
# 119997  10267   700.0       0.0         0.068180        27549.714659
# 119998  10240  1616.0     106.0         0.168164        56967.384382
# 119999   9931   770.0       0.0         0.077535        38466.837135
#
#         video_length_minutes  subscribers  category  device  country  year  \
# ...

# %%
y
# Out:
# 0         203.178237
# 1         140.880508
# 2         360.134008
# 3         224.638261
# 4         165.514388
#              ...
# 119995    280.986396
# 119996    354.612981
# 119997    203.643106
# 119998    351.525811
# 119999    253.842824
# Name: ad_revenue_usd, Length: 120000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((96000, 16), (24000, 16), (96000,), (24000,))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train_scaled, y_train)

y_pred = lr.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
from sklearn.ensemble import RandomForestRegressor


model = RandomForestRegressor().fit(x_train, y_train)

y_pred = model.predict(x_test)

print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print( r2_score(y_test, y_pred))
# Out:
# 3.4477176721745004
# 199.3385733886632
# 0.9482184309137682

# %%
import xgboost as xgb

model=xgb.XGBRFRegressor().fit(x_train,y_train)

y_predict=model.predict(x_test)
print(mean_absolute_error(y_test,y_predict))
print(mean_squared_error(y_test,y_predict))
print(r2_score(y_test,y_predict))
# Out:
# 7.365186004118767
# 264.67291781769205
# 0.9312467288881943

# %%
from sklearn.ensemble import AdaBoostRegressor

model=AdaBoostRegressor().fit(x_train,y_train)

y_predict=model.predict(x_test)
print(mean_absolute_error(y_test,y_predict))
print(mean_squared_error(y_test,y_predict))
print(r2_score(y_test,y_predict))
# Out:
# 13.807184397960105
# 393.17580316684615
# 0.8978659289638693

# %%
from sklearn.ensemble import GradientBoostingRegressor #winner


model = GradientBoostingRegressor().fit(x_train, y_train)

y_pred = model.predict(x_test)

print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print( r2_score(y_test, y_pred))
# Out:
# 3.9119432803741176
# 191.12340982872647
# 0.950352458724854

# %%
print(x_train.index[:10])
print(x_test.index[:10])
# Out:
# Index([73158, 13786, 117147, 81609, 90491, 46550, 86508, 88994, 53363, 71593], dtype='int64')
# Index([75019, 9934, 57338, 12730, 45900, 51848, 13595, 83967, 34169, 53289], dtype='int64')

# %%
print("x_test values:")
print(x_test.head(10))
# Out:
# x_test values:
#        views   likes  comments  Engagement_Rate  watch_time_minutes  \
# 75019  10069   249.0     137.0         0.038335        21410.840993
# 9934    9966  1508.0     299.0         0.181316        46094.507892
# 57338  10187  1772.0     488.0         0.221851        32358.756064
# 12730  10039  1369.0     343.0         0.170535        48312.629903
# 45900   9997  1077.0     141.0         0.121837        31790.717902
# 51848  10044  1941.0     154.0         0.208582        34857.764857
# 13595  10156  1857.0     149.0         0.197519        28102.798461
# 83967   9999   979.0      88.0         0.106711        29483.221271
# 34169  10092  1139.0     393.0         0.151803        44276.203961
# 53289  10238   438.0     213.0         0.063587        27779.635527
#
#        video_length_minutes  subscribers  category  device  country  year  \
# 75019             12.460533        10243       0.0     1.0      0.0  2025
# ...

# %%
print("y_test values:")
print(y_test.head(10))
# Out:
# y_test values:
# 75019    160.039939
# 9934     300.298525
# 57338    244.478200
# 12730    309.503500
# 45900    222.900968
# 51848    252.678867
# 13595    219.886226
# 83967    209.437323
# 34169    287.656053
# 53289    195.501053
# Name: ad_revenue_usd, dtype: float64

# %%
print("x_train values:")
print(x_train.head(10))
# Out:
# x_train values:
#         views   likes  comments  Engagement_Rate  watch_time_minutes  \
# 73158    9963  1500.0     211.0         0.171735        32278.219679
# 13786   10017   260.0     442.0         0.070081        26210.996516
# 117147  10133   555.0     148.0         0.069377        37411.803064
# 81609    9944  1049.0     112.0         0.116754        56501.265514
# 90491   10146  1888.0       0.0         0.186083        45456.999881
# 46550    9898   316.0     385.0         0.070822        39441.459716
# 86508    9988   625.0     122.0         0.074790        36871.859368
# 88994    9982  1818.0     174.0         0.199559        59351.591659
# 53363   10097  1882.0     498.0         0.235714        50100.257710
# 71593   10166     0.0      58.0         0.005705        56050.973182
#
#         video_length_minutes  subscribers  category  device  country  year  \
# 73158              12.669682       427095       0.0     0.0      1.0  2024
# ...

# %%
print("y_train values:")
print(y_train.head(10))
# Out:
# y_train values:
# 73158     233.495524
# 13786     187.830707
# 117147    241.258902
# 81609     338.143896
# 90491     303.197986
# 46550     249.568973
# 86508     238.714054
# 88994     366.062545
# 53363     329.714689
# 71593     333.327718
# Name: ad_revenue_usd, dtype: float64

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib


y_log = np.log1p(y)
num_cols = x.columns.tolist()
cat_cols = []

preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),

    ]
)


pipeline = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", GradientBoostingRegressor())
])


x_train, x_test, y_train, y_test = train_test_split(x, y_log, test_size=0.2, random_state=42)

pipeline.fit(x_train, y_train)


pred = pipeline.predict(x_test)
pred_real = np.expm1(pred)

print("MAE:", mean_absolute_error(np.expm1(y_test), pred_real))
print("MSE:", mean_squared_error(np.expm1(y_test), pred_real))
print("R2:", r2_score(np.expm1(y_test), pred_real))


joblib.dump(pipeline, "/content/drive/MyDrive/best_pipeline_improved.joblib")

print("Model saved successfully!")
# Out:
# MAE: 3.845586897216039
# MSE: 188.00055923323504
# R2: 0.9509325918653279
# Model saved successfully!
